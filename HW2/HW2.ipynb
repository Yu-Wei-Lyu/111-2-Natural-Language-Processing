# %% [markdown]
# ## 1. 先提取需要的套件和製作提取資料的 method

# %%
import nltk
from nltk.classify import NaiveBayesClassifier
from nltk.metrics import *
from sklearn.metrics import *

# %%
def read_conll_file(file_name):
    current_item = []
    current_words = []
    current_tag_classes = []
    with open(file_name, encoding='utf-8') as conll:
        for line in conll:
            line = line.strip()
            if line and len(line.split()) == 2: # 排除空行和參數不完整的行
                word, tag_class = line.split()
                current_item.append((word, tag_class))
                current_words.append(word)
                current_tag_classes.append(tag_class)
    return current_item

def word_feats(words):
    return dict([(word, True) for word in words])

# %% [markdown]
# ## 2. 提取資料

# %%
train_set=[(word_feats(words), tag_classes) for (words, tag_classes) in read_conll_file('e.conll')]
test_set=[(word_feats(words), tag_classes) for (words, tag_classes) in read_conll_file('f.conll')]
# Out:
# [({'#': True, 'B': True, 'R': True, 'E': True, 'A': True, 'K': True, 'I': True, 'N': True, 'G': True, 'W': True, 'S': True}, 'O'), ({'M': True, 'A': True, 'L': True, 'Y': True, 'S': True, 'I': True}, 'B-ORG'), ({'A': True, 'I': True, 'R': True, 'L': True, 'N': True, 'E': True, 'S': True}, 'I-ORG'), ({'F': True, 'L': True, 'I': True, 'G': True, 'H': True, 'T': True}, 'O'), ({'#': True, 'M': True, 'H': True, '1': True, '7': True}, 'O'), ({'C': True, 'O': True, 'N': True, 'F': True, 'I': True, 'R': True, 'M': True, 'E': True, 'D': True}, 'O'), ({'S': True, 'H': True, 'O': True, 'T': True}, 'O'), ({'D': True, 'O': True, 'W': True, 'N': True}, 'O'), ({'O': True, 'V': True, 'E': True, 'R': True}, 'O'), ({'#': True, 'D': True, 'O': True, 'N': True, 'E': True, 'T': True, 'S': True, 'K': True}, 'B-LOC'), ({'O': True, 'B': True, 'L': True, 'A': True, 'S': True, 'T': True}, 'I-LOC'), ({',': True}, 'O'), ({'S': True, 'H': True, 'O': True, 'R': True, 'T': True, 'L': True, 'Y': True}, 'O'), ({'B': True, 'E': True, 'F': True, 'O': True, 'R': True}, 'O'), ({'R': True, 'E': True, 'A': True, 'C': True, 'H': True, 'I': True, 'N': True, 'G': True}, 'O'), ({'R': True, 'U': True, 'S': True, 'I': True, 'A': True, 'N': True}, 'B-LOC'), ({'A': True, 'I': True, 'R': True}, 'O'), ({'S': True, 'P': True, 'A': True, 'C': True, 'E': True}, 'O'), ({'H': True, 'e': True, 'r': True}, 'O'), ({"'": True, 's': True}, 'O'), ({'a': True}, 'O'), ({'r': True, 'o': True, 'u': True, 't': True, 'e': True}, 'O'), ({'m': True, 'a': True, 'p': True}, 'O'), ({'o': True, 'f': True}, 'O'), ({'@': True}, 'B-ORG'), ({'M': True, 'A': True, 'S': True}, 'B-ORG'), ({'#': True, 'M': True, 'H': True, '1': True, '7': True, ',': True}, 'O'), ({'w': True, 'h': True, 'i': True, 'c': True}, 'O'), ({'@': True}, 'B-ORG'), ({'f': True, 'l': True, 'i': True, 'g': True, 'h': True, 't': True, 'a': True, 'w': True, 'r': True, 'e': True}, 'B-ORG'), ({'l': True, 'o': True, 's': True, 't': True}, 'O'), ({'t': True, 'r': True, 'a': True, 'c': True, 'k': True}, 'O'), ({'o': True, 'f': True}, 'O'), ({'r': True, 'i': True, 'g': True, 'h': True, 't': True}, 'O'), ({'a': True, 't': True}, 'O'), ({'t': True, 'h': True, 'e': True}, 'O'), ({'U': True, 'k': True, 'r': True, 'a': True, 'i': True, 'n': True, 'e': True}, 'B-LOC'), ({'/': True}, 'O'), ({'P': True, 'o': True, 'l': True, 'a': True, 'n': True, 'd': True}, 'B-LOC'), ({'b': True, 'o': True, 'r': True, 'd': True, 'e': True}, 'I-LOC'), ({'h': True, 't': True, 'p': True, ':': True, '/': True, '.': True, 'c': True, 'o': True, 'I': True, 'G': True, 'v': True, 'Q': True, 'J': True, 'n': True, 'k': True, 'U': True, '7': True, 'B': True}, 'O'), ({'C': True, 'a': True, 'n': True}, 'O'), ({'s': True, 'o': True, 'm': True, 'e': True, 'b': True, 'd': True, 'y': True}, 'O'), ({'c': True, 'o': True, 'n': True, 'f': True, 'i': True, 'r': True, 'm': True}, 'O'), ({'t': True, 'h': True, 'i': True, 's': True}, 'O'), ({'.': True}, 'O'), ({'R': True, 'T': True}, 'O'), ({'@': True, 'K': True, 'e': True, 'n': True, 'y': True, 'S': True, 'k': True, 'N': True, 'w': True, 's': True}, 'O'), ({':': True}, 'O'), ({'R': True, 'e': True, 'p': True, 'o': True, 'r': True, 't': True, 's': True}, 'O'), ({'M': True, 'a': True, 'l': True, 'y': True, 's': True, 'i': True}, 'B-ORG'), ({'A': True, 'i': True, 'r': True, 'l': True, 'n': True, 'e': True, 's': True}, 'I-ORG'), ({'M': True, 'H': True}, 'O'), ({'1': True, '7': True}, 'O'), ({'h': True, 'a': True, 's': True}, 'O'), ({'c': True, 'r': True, 'a': True, 's': True, 'h': True, 'e': True, 'd': True}, 'O'), ({'n': True, 'e': True, 'a': True, 'r': True}, 'O'), ({'U': True, 'k': True, 'r': True, 'a': True, 'i': True, 'n': True, 'e': True}, 'B-LOC'), ({"'": True, 's': True}, 'O'), ({'b': True, 'o': True, 'r': True, 'd': True, 'e': True}, 'O'), ({'w': True, 'i': True, 't': True, 'h': True}, 'O'), ({'R': True, 'u': True, 's': True, 'i': True, 'a': True}, 'B-LOC'), ({'.': True}, 'O'), ({'#': True, 'M': True, 'H': True, '1': True, '7': True}, ...

# %% [markdown]
# ## 3. 使用Bayes分類器進行訓練，再進行預測並取得結果

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)
test_predict = []
testing = []
for item in test_set:
    test_predict.append(classifier.classify(item[0]))
    testing.append(item[1])

# %% [markdown]
# ## 4.使用Bayes分類器進行訓練、再進行預測並取得結果

# %%
precision = precision_score(testing, test_predict, average=None)
recall = recall_score(testing, test_predict, average=None)
f1 = f1_score(testing, test_predict, average=None)
accuracy = nltk.classify.accuracy(classifier, test_set)

print(f'Precision： {precision}')
print(f'Recall： {recall}')
print(f'F1-score： {f1}')
print(f'Accuracy： {accuracy}')
# Out:
# Precision： [0.0872056  0.2125576  0.27983539 0.01388889 0.01173709 0.00884956
#  0.92682038]
# Recall： [0.21540881 0.33853211 0.02566038 0.00480769 0.06097561 0.01115242
#  0.92254171]
# F1-score： [0.12415043 0.2611465  0.04701002 0.00714286 0.01968504 0.00986842
#  0.9246761 ]
# Accuracy： 0.8064925899788286
